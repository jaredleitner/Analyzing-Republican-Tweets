# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(9,6))
plt.hist(res,200,normed=False,color='cornflowerblue')
plt.xlabel('The ratio of total favorite count to total retweet count')  
plt.ylabel('Number of people')  
plt.title(r'Histogram of Ratio of 434 Politician')
plt.annotate("Trump's here!", xy=(2.7668671138897314, 1), xytext=(2.4, 4),color='indianred',size=15,
            arrowprops=dict(facecolor='indianred', shrink=0.01))
plt.savefig("Histogram of Ratio of 434 Politician")
plt.show()

# %%
labels   = ['Average', 'Ted Cruz', 'Jeb Bush','John Kasich','Marco Rubio' ,'Donald Trump']
 
quants   = [0.48630677648987886, 1.639247104424421, 2.2379884868003956,  2.2452721228233554,2.377415087983513,2.7898139491304836]

import matplotlib.pyplot as plt
plt.figure(figsize=(9,6))
plt.title(r'Barchart of Ratio of 5 Candidate')
plt.ylabel('The ratio of total favorite count to total retweet count') 
plt.bar(range(len(quants)), quants, tick_label=labels,color='cornflowerblue',width=0.4)
plt.savefig("Barchart of Ratio of 5 Candidate")
plt.show()
