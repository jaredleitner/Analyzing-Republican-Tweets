# %%
#!/usr/bin/env python
# encoding: utf-8

import tweepy #https://github.com/tweepy/tweepy
import csv

import user_credentials as cred
consumer_key = cred.consumer_key
consumer_secret = cred.consumer_secret
access_key = cred.access_key
access_secret = cred.access_secret

# %%
def get_all_tweets(screen_name):
    #Twitter only allows access to a users most recent 3240 tweets with this method

    #authorize twitter, initialize tweepy
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_key, access_secret)
    api = tweepy.API(auth)
    
    #initialize a list to hold all the tweepy Tweets
    alltweets = []	
    
    #make initial request for most recent tweets (200 is the maximum allowed count)
    new_tweets = api.user_timeline(screen_name = screen_name,count=200)
    
    #save most recent tweets
    alltweets.extend(new_tweets)
    
    #save the id of the oldest tweet less one
    oldest = alltweets[-1].id - 1

    #keep grabbing tweets until there are no tweets left to grab
    while len(new_tweets) > 0:
        print("getting tweets before %s" % (oldest))

        #all subsiquent requests use the max_id param to prevent duplicates
        new_tweets = api.user_timeline(screen_name = screen_name,count=200,max_id=oldest)

        #save most recent tweets
        alltweets.extend(new_tweets)
        
        #update the id of the oldest tweet less one
        oldest = alltweets[-1].id - 1
        
        print("...%s tweets downloaded so far" % (len(alltweets)))

    #transform the tweepy tweets into a 2D array that will populate the csv	
    outtweets = [[tweet.id_str, tweet.created_at, tweet.text.encode("utf-8")] for tweet in alltweets]
    
    #write the csv	
    #with open('%s_tweets.csv' % screen_name, 'wb') as f:
    #    writer = csv.writer(f)
    #    writer.writerow(["id","created_at","text"])
    #    writer.writerows(outtweets)

    return outtweets

# %%
#if __name__ == '__main__':
#    pass in the username of the account you want to download
#    get_all_tweets("tedcruz")

tweets = get_all_tweets("GovMikeHuckabee")
print(tweets)
# Out:
# getting tweets before 1086261115510755328
# ...400 tweets downloaded so far
# getting tweets before 1064198678263603199
# ...600 tweets downloaded so far
# getting tweets before 1050177566882099199
# ...800 tweets downloaded so far
# getting tweets before 1038189705370763263
# ...1000 tweets downloaded so far
# getting tweets before 1028241087285129215
# ...1200 tweets downloaded so far
# getting tweets before 1021010672119894016
# ...1400 tweets downloaded so far
# getting tweets before 1008079725410029567
# ...1600 tweets downloaded so far
# getting tweets before 997807286352572416
# ...1800 tweets downloaded so far
# getting tweets before 988159011458633727
# ...2000 tweets downloaded so far
# getting tweets before 970068806948311039
# ...2200 tweets downloaded so far
# getting tweets before 950603210376564736
# ...2400 tweets downloaded so far
# getting tweets before 925332344084553727
# ...2600 tweets downloaded so far
# getting tweets before 901173363401478145
# ...2800 tweets downloaded so far
# getting tweets before 879869709910495231
# ...3000 tweets downloaded so far
# getting tweets before 860560575142797313
# ...3199 tweets downloaded so far
# getting tweets before 841843644189540353
# ...3219 tweets downloaded so far
# getting tweets before 840190470840037375
# ...3219 tweets downloaded so far
# [['1100546465779384321', datetime.datetime(2019, 2, 27, 0, 1, 39), b'Oops. Got canned and won\'t be on Hannity after all. I was triggered by this, but @FoxNews has provided me a "safe s\xe2\x80\xa6 https://t.co/HHUsZibwAp'], ['1100532766083567618', datetime.datetime(2019, 2, 26, 23, 7, 13), b"I'll be on @seanhannity 9pmET and will challenge Sean about his riding scooter in Hanoi to get to his @FoxNews  sho\xe2\x80\xa6 https://t.co/jkCuAnYrXm"], ['1100490980883607552', datetime.datetime(2019, 2, 26, 20, 21, 10), b'I make good barbecue but Quito at Lillie\xe2\x80\x99s Q in Miramar Beach FL near Destin makes GREAT food! And I love his signs\xe2\x80\xa6 https://t.co/KRigD2TBcH'], ['1100410490990211073', datetime.datetime(2019, 2, 26, 15, 1, 20), b'Bernie Sanders has no trouble calling President Trump an authoritarian, but still can\xe2\x80\x99t bring himself to call Venez\xe2\x80\xa6 https://t.co/WNFy9kIO6I'], ['1100394527448358914', datetime.datetime(2019, 2, 26, 13, 57, 54), b'Correction, Fin!  @PressSec has arrived.  @realDonaldTrump is on the plane with her. https://t.co/brwui4Qtlj'], ['1100394245570088960', datetime.datetime(2019, 2, 26, 13, 56, 47), b'Is Tillis trying to replace disgraced Jeff Flake?  Did someone scare him in an elevator?  Maybe NC can send a Repub\xe2\x80\xa6 https://t.co/YIUKkt3m4o'], ['1100369625865510912', datetime.datetime(2019, 2, 26, 12, 18, 57), b'Cheaper option than $93 trillion "Green New Deal" is spend $10 trillion on "New Space Deal" and send all the "woke"\xe2\x80\xa6 https://t.co/tDtj5s9fIX'], ['1100353887456976896', datetime.datetime(2019, 2, 26, 11, 16, 25), b"Wake up slackers! I'll be on @foxandfriends on @FoxNews at 7:30am ET-I'm like trying to like better like understand\xe2\x80\xa6 https://t.co/9IS6iFZw2q"], ['1100249103253098497', datetime.datetime(2019, 2, 26, 4, 20, 2), b'If Dems want 2020 to be whether we should murder freshly born babies and forbid more children b/c of "climate chang\xe2\x80\xa6 https://t.co/QW6dJZawF5'], ['1100226247072890880', datetime.datetime(2019, 2, 26, 2, 49, 13), b"I'll be on @ShannonBream on @FoxNews at 11pmET but it's worth staying up to see as I'll reveal how Spike Lee got hi\xe2\x80\xa6 https://t.co/zBzB2FQHcn"], ['1100182891269681152', datetime.datetime(2019, 2, 25, 23, 56, 56), b'If you want to make decisions based on socialist ideas then don\xe2\x80\x99t reproduce. The rest of us wont do generational su\xe2\x80\xa6 https://t.co/kzLn5i0s9E'], ['1100173217199767552', datetime.datetime(2019, 2, 25, 23, 18, 29), b"What you may have missed in the Fake News you get on my feature, ICYMI from https://t.co/MTf4xbnNsG  Here's this we\xe2\x80\xa6 https://t.co/KCzhRnKwzH"], ['1100103110989627394', datetime.datetime(2019, 2, 25, 18, 39, 55), b'U can\'t make this up!  AOC &amp; other "progressives" say a women should control her body if she wants to kill a baby (\xe2\x80\xa6 https://t.co/q8tJtkHDgi'], ['1100068404952731649', datetime.datetime(2019, 2, 25, 16, 22), b"ICYMI (and you shouldn't have!) watch and be in absolute awe.  I mean AWE!  Shock and awe, really.  Or maybe Awwww.\xe2\x80\xa6 https://t.co/hA5nytPcx3"], ['1099831701453393920', datetime.datetime(2019, 2, 25, 0, 41, 26), b"Watch @AmericaNewsroom Mon at 9am ET on @FoxNews but don't tell @BillHemmer or @SandraSmithFox I'll be on-I'm going\xe2\x80\xa6 https://t.co/0XUs6taRgi"], ['1099699886264594433', datetime.datetime(2019, 2, 24, 15, 57, 38), b'2nite my @TBN show repeats w/ @GarySinise @TimTebow @RickySkaggs and @gatlinbrothers 8/11pm ET. Unlike the boring O\xe2\x80\xa6 https://t.co/M2CvDcfGMV'], ['1099640090186399744', datetime.datetime(2019, 2, 24, 12, 0, 2), b"Wake up! Hurry and turn on TV to @foxandfriends on @FoxNews because at 8am ET/7CT I'll demonstrate how to confuse l\xe2\x80\xa6 https://t.co/rMkUoygSSt"], ['1099448694775209985', datetime.datetime(2019, 2, 23, 23, 19, 30), b'2nite: @GarySinise @RickySkaggs @TimTebow @gatlinbrothers and more at 8/11pm ET on https://t.co/MTf4xbnNsG on @TBN\xe2\x80 ...
